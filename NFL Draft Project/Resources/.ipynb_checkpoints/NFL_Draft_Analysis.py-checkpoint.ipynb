# %%
import pandas as pd

# %%
draft_df = pd.read_csv('draft.csv')
game_df = pd.read_csv('gameParticipation.csv')
player_df = pd.read_csv('players.csv')

# %%
draft_df.head()
# Out:
#    playerId  draft  round  pick  draftTradeValue draftTeam position  teamId  \
# 0  19770001   1977    1.0     1           3000.0        TB       RB    4900
# 1  19770002   1977    1.0     2           2600.0       DAL       RB    1200
# 2  19770003   1977    1.0     3           2200.0       CIN       DE     920
# 3  19770004   1977    1.0     4           1800.0       NYJ       OT    3430
# 4  19770005   1977    1.0     5           1700.0       NYG       DE    3410
#
#   nameFirst nameLast  ...         dob  ageAtDraft  \
# 0     Ricky     Bell  ...  1955-04-08   22.084932
# 1      Tony  Dorsett  ...  1954-04-07   23.087671
# 2     Eddie  Edwards  ...  1954-04-25   23.038356
# 3    Marvin   Powell  ...  1955-08-30   21.690411
# 4      Gary    Jeter  ...  1955-01-24   22.287671
#
#                                     playerProfileUrl     homeCity homeState  \
# 0  http://www.nfl.com/player/RickyBell/2509366/pr...      Houston        TX
# ...

# %%
game_df.head()
# Out:
#    gamePartId  gameId  teamId  playerId gamePartUnit  gamePartSnapCount  \
# 0    12100001   56473    3800  20140091      offense                 39
# 1    12100002   56473    3800  20100645      offense                 33
# 2    12100003   56473    3800  20120112      offense                 30
# 3    12100004   56473    3800  20100205      offense                 30
# 4    12100005   56473    3800  20090213      offense                 30
#
#   nameFirst nameLast      nameFull position  ...         dob  ageAtDraft  \
# 0      John    Brown    John Brown       WR  ...  1990-04-03   24.112329
# 1      John    Estes    John Estes        C  ...  1987-03-25   23.093151
# 2     Bobby   Massie  Bobby Massie       OT  ...  1989-08-01   22.750685
# 3       Ted   Larsen    Ted Larsen       OG  ...  1987-06-13   22.873973
# 4      Paul  Fanaika  Paul Fanaika       OG  ...  1986-04-09   23.060274
#
#                                     playerProfileUrl   homeCity  homeState  \
# ...

# %%
player_df.head()
# Out:
#    playerId nameFirst nameLast       nameFull position  collegeId    nflId  \
# 0  19770001     Ricky     Bell     Ricky Bell       RB      90089  2509366
# 1  19770002      Tony  Dorsett   Tony Dorsett       RB      15260  2513084
# 2  19770003     Eddie  Edwards  Eddie Edwards       DE      33124  2513479
# 3  19770004    Marvin   Powell  Marvin Powell       OT      90089  2523462
# 4  19770005      Gary    Jeter     Gary Jeter       DE      90089  2517530
#
#    combineId     college  heightInches  ...         dob ageAtDraft  \
# 0        NaN         USC          74.0  ...  1955-04-08  22.084932
# 1        NaN  Pittsburgh          71.0  ...  1954-04-07  23.087671
# 2        NaN  Miami (FL)          77.0  ...  1954-04-25  23.038356
# 3        NaN         USC          77.0  ...  1955-08-30  21.690411
# 4        NaN         USC          76.0  ...  1955-01-24  22.287671
#
#                                     playerProfileUrl     homeCity homeState  \
# ...

# %%
#Using Groupby to organize the game DF
game_df2 = game_df.groupby(['nameFull'])
game_df2.head()
# Out:
#         gamePartId  gameId  teamId  playerId   gamePartUnit  \
# 0         12100001   56473    3800  20140091        offense
# 1         12100002   56473    3800  20100645        offense
# 2         12100003   56473    3800  20120112        offense
# 3         12100004   56473    3800  20100205        offense
# 4         12100005   56473    3800  20090213        offense
# ...            ...     ...     ...       ...            ...
# 405757     6515105   57899    5110  20190736  special teams
# 405759     6515107   57899    5110  20190474  special teams
# 405809     6515157   57899     325  20181249  special teams
# 415495     6559772   58035    2520  20180227  special teams
# 420016     6581970   58108    3430  20190904  special teams
#
#         gamePartSnapCount nameFirst  nameLast          nameFull position  ...  \
# 0                      39      John     Brown        John Brown       WR  ...
# 1                      33      John     Estes        John Estes        C  ...
# ...

# %%
game_df.shape
# Out:
# (423185, 26)

# %%
Evander_Hood_Data = game_df[game_df['nameFull'] == 'Evander Hood']
Evander_Hood_Data.head(5)
# Out:
#        gamePartId  gameId  teamId  playerId gamePartUnit  gamePartSnapCount  \
# 15060    12201081   56380    2250  20090032      defense                 19
# 15061    12201081   56380    2250  20090032      defense                 19
# 15062    12201081   56380    2250  20090032      defense                 19
# 15063    12201081   56380    2250  20090032      defense                 19
# 15064    12201081   56380    2250  20090032      defense                 19
#
#       nameFirst nameLast      nameFull position  ...         dob  ageAtDraft  \
# 15060   Evander     Hood  Evander Hood       DT  ...  1987-02-16    22.20274
# 15061   Evander     Hood  Evander Hood       DT  ...  1987-02-16    22.20274
# 15062   Evander     Hood  Evander Hood       DT  ...  1987-02-16    22.20274
# 15063   Evander     Hood  Evander Hood       DT  ...  1987-02-16    22.20274
# 15064   Evander     Hood  Evander Hood       DT  ...  1987-02-16    22.20274
#
# ...

# %%
Evander_Hood_Data.nunique()
# Out:
# gamePartId           82
# gameId               42
# teamId                3
# playerId              1
# gamePartUnit          2
# gamePartSnapCount    36
# nameFirst             1
# nameLast              1
# nameFull              1
# position              1
# collegeId             1
# nflId                 2
# combineId             1
# college               1
# heightInches          1
# weight                1
# dob                   1
# ageAtDraft            1
# playerProfileUrl      1
# homeCity              1
# homeState             1
# homeCountry           1
# highSchool            1
# hsCity                1
# hsState               1
# hsCountry             1
# dtype: int64

# %%
Chris_Jones_Houstonhs_Data = game_df[game_df['playerId'] == 20160037]
Chris_Jones_Houstonhs_Data
# Out:
#         gamePartId  gameId  teamId  playerId   gamePartUnit  \
# 171359     5495506   57490    2310  20160037        defense
# 172050     5427811   57279    2310  20160037        defense
# 172651     5432330   57297    2310  20160037        defense
# 173177     5436761   57310    2310  20160037        defense
# 173763     5441344   57322    2310  20160037        defense
# ...            ...     ...     ...       ...            ...
# 418493     6573561   58084    2310  20160037  special teams
# 419552     6578070   58104    2310  20160037  special teams
# 420416     6582363   58113    2310  20160037  special teams
# 421110     6586506   58138    2310  20160037  special teams
# 422719     6591542   58148    2310  20160037  special teams
#
#         gamePartSnapCount nameFirst nameLast     nameFull position  ...  \
# 171359                 20     Chris    Jones  Chris Jones       DT  ...
# 172050                 39     Chris    Jones  Chris Jones       DT  ...
# ...

# %%
Chris_Jones_Houstonhs_Data.nunique()
# Out:
# gamePartId           62
# gameId               37
# teamId                1
# playerId              1
# gamePartUnit          2
# gamePartSnapCount    28
# nameFirst             1
# nameLast              1
# nameFull              1
# position              1
# collegeId             1
# nflId                 1
# combineId             1
# college               1
# heightInches          1
# weight                1
# dob                   1
# ageAtDraft            1
# playerProfileUrl      1
# homeCity              1
# homeState             1
# homeCountry           1
# highSchool            1
# hsCity                0
# hsState               1
# hsCountry             1
# dtype: int64

# %%
Tom_Brady_Data = game_df[game_df['playerId'] == 20000199]
Tom_Brady_Data
# Out:
#         gamePartId  gameId  teamId  playerId gamePartUnit  gamePartSnapCount  \
# 1525      12101526   56248    3200  20000199      offense                 71
# 5046      12105047   56359    3200  20000199      offense                 56
# 5812      12105813   56329    3200  20000199      offense                 70
# 6702      12106703   56230    3200  20000199      offense                 38
# 7215      12107209   56176    3200  20000199      offense                 86
# ...            ...     ...     ...       ...          ...                ...
# 381837     6373107   58090    3200  20000199      offense                 87
# 382480     6377695   58104    3200  20000199      offense                 67
# 382828     6381987   58110    3200  20000199      offense                 65
# 383584     6386691   58126    3200  20000199      offense                 73
# 384307     6391365   58150    3200  20000199      offense                 61
#
# ...

# %%
Tom_Brady_Data.nunique()
# Out:
# gamePartId           61
# gameId               61
# teamId                1
# playerId              1
# gamePartUnit          2
# gamePartSnapCount    33
# nameFirst             1
# nameLast              1
# nameFull              1
# position              1
# collegeId             1
# nflId                 1
# combineId             1
# college               1
# heightInches          1
# weight                1
# dob                   1
# ageAtDraft            1
# playerProfileUrl      1
# homeCity              1
# homeState             1
# homeCountry           1
# highSchool            1
# hsCity                1
# hsState               1
# hsCountry             1
# dtype: int64

# %%
#Tom Brady has played approximately 300 games. Suspect this is do to his multiple player IDs
Tom_Brady_Data_pi = Tom_Brady_Data[Tom_Brady_Data['playerId'] == 20000199]
Tom_Brady_Data_pi.head()
# Out:
#       gamePartId  gameId  teamId  playerId gamePartUnit  gamePartSnapCount  \
# 1525    12101526   56248    3200  20000199      offense                 71
# 5046    12105047   56359    3200  20000199      offense                 56
# 5812    12105813   56329    3200  20000199      offense                 70
# 6702    12106703   56230    3200  20000199      offense                 38
# 7215    12107209   56176    3200  20000199      offense                 86
#
#      nameFirst nameLast   nameFull position  ...         dob  ageAtDraft  \
# 1525       Tom    Brady  Tom Brady       QB  ...  1977-08-03   22.715068
# 5046       Tom    Brady  Tom Brady       QB  ...  1977-08-03   22.715068
# 5812       Tom    Brady  Tom Brady       QB  ...  1977-08-03   22.715068
# 6702       Tom    Brady  Tom Brady       QB  ...  1977-08-03   22.715068
# 7215       Tom    Brady  Tom Brady       QB  ...  1977-08-03   22.715068
#
# ...

# %%
Tom_Brady_Data_pi.nunique()
# Out:
# gamePartId           61
# gameId               61
# teamId                1
# playerId              1
# gamePartUnit          2
# gamePartSnapCount    33
# nameFirst             1
# nameLast              1
# nameFull              1
# position              1
# collegeId             1
# nflId                 1
# combineId             1
# college               1
# heightInches          1
# weight                1
# dob                   1
# ageAtDraft            1
# playerProfileUrl      1
# homeCity              1
# homeState             1
# homeCountry           1
# highSchool            1
# hsCity                1
# hsState               1
# hsCountry             1
# dtype: int64

# %%
Tom_Brady_Data_pi.head()
# Out:
#       gamePartId  gameId  teamId  playerId gamePartUnit  gamePartSnapCount  \
# 1525    12101526   56248    3200  20000199      offense                 71
# 5046    12105047   56359    3200  20000199      offense                 56
# 5812    12105813   56329    3200  20000199      offense                 70
# 6702    12106703   56230    3200  20000199      offense                 38
# 7215    12107209   56176    3200  20000199      offense                 86
#
#      nameFirst nameLast   nameFull position  ...         dob  ageAtDraft  \
# 1525       Tom    Brady  Tom Brady       QB  ...  1977-08-03   22.715068
# 5046       Tom    Brady  Tom Brady       QB  ...  1977-08-03   22.715068
# 5812       Tom    Brady  Tom Brady       QB  ...  1977-08-03   22.715068
# 6702       Tom    Brady  Tom Brady       QB  ...  1977-08-03   22.715068
# 7215       Tom    Brady  Tom Brady       QB  ...  1977-08-03   22.715068
#
# ...
